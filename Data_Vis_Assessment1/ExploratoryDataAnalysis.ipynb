# %%
# %matplotlib widget

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Review_Dataset.csv") 

df
# Out:
#        Age                                        Review Text  Rating  \
# 0       33  Absolutely wonderful - silky and sexy and comf...       4
# 1       34  Love this dress!  it's sooo pretty.  i happene...       5
# 2       60  I had such high hopes for this dress and reall...       3
# 3       50  I love, love, love this jumpsuit. it's fun, fl...       5
# 4       47  This shirt is very flattering to all due to th...       5
# ...    ...                                                ...     ...
# 22623   34  I was very happy to snag this dress at such a ...       5
# 22624   48  It reminds me of maternity clothes. soft, stre...       3
# 22625   31  This fit well, but the top was very see throug...       3
# 22626   28  I bought this dress for a wedding i have this ...       3
# 22627   52  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# ...

# %%
df.dropna()
# Out:
#        Age                                        Review Text  Rating  \
# 0       33  Absolutely wonderful - silky and sexy and comf...       4
# 1       34  Love this dress!  it's sooo pretty.  i happene...       5
# 2       60  I had such high hopes for this dress and reall...       3
# 3       50  I love, love, love this jumpsuit. it's fun, fl...       5
# 4       47  This shirt is very flattering to all due to th...       5
# ...    ...                                                ...     ...
# 22623   34  I was very happy to snag this dress at such a ...       5
# 22624   48  It reminds me of maternity clothes. soft, stre...       3
# 22625   31  This fit well, but the top was very see throug...       3
# 22626   28  I bought this dress for a wedding i have this ...       3
# 22627   52  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# ...

# %%
df.plot.hist(column='Rating',bins=[0,1,2,3,4,5,6])
# Out:
# <Axes: ylabel='Frequency'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 5    12527
# 4     4908
# 3     2823
# 2     1549
# 1      821
# Name: count, dtype: int64

# %%
12527+4908+2823+1549+821
# Out:
# 22628

# %%
df.columns
# Out:
# Index(['Age', 'Review Text', 'Rating', 'Recommended IND',
#        'Positive Feedback Count', 'Division Name', 'Department Name',
#        'Class Name'],
#       dtype='object')

# %%
df_pos = df.loc[ (df.Rating>4)&(df['Recommended IND']>0)&(df['Positive Feedback Count']>0)].copy()
df_pos
# Out:
#        Age                                        Review Text  Rating  \
# 1       34  Love this dress!  it's sooo pretty.  i happene...       5
# 4       47  This shirt is very flattering to all due to th...       5
# 6       39  I aded this in my basket at hte last mintue to...       5
# 11      39  This dress is perfection! so pretty and flatte...       5
# 12      53  More and more i find myself reliant on the rev...       5
# ...    ...                                                ...     ...
# 22608   42  I wore this dress to work the other day and go...       5
# 22611   60  I worry when i have an elastic waist, or somet...       5
# 22612   35  I love this little chemise! the adjustable str...       5
# 22616   29  Great quality and extremely flattering. bonus ...       5
# 22627   52  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# ...

# %%
df_neg = df.loc[ (df.Rating<2)&(df['Recommended IND']<1)&(df['Positive Feedback Count']>0)].copy()
df_neg
# Out:
#        Age                                        Review Text  Rating  \
# 85      58  I was really hoping to like this, but it did n...       1
# 107     44  This is so thin and poor quality. especially f...       1
# 156     52  The title says it all....this fabric of this t...       1
# 200     44  Love the fabric of this shirt even though it w...       1
# 205     67  The skirt that i received had very little blue...       1
# ...    ...                                                ...     ...
# 22251   48  I love the colors. however, $200 is a lot to p...       1
# 22268   48  I was very shocked to receive this dress with ...       1
# 22286   32  I'm so disappointed this dress didn't work out...       1
# 22402   46  Pants are overpriced and very uncomfortable. t...       1
# 22496   57  I loved the print and fabric of this dress whe...       1
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# ...

# %%
!  pip install wordcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 3.0 MB/s eta 0:00:003.7 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.9.2-cp310-cp310-macosx_10_9_universal2.whl size=217714 sha256=c2b96bc7a663a56a9f00ebecddf373278cbbffac1dbc4a36d20ab0321d31fc43
#   Stored in directory: /Users/ameliamcdowell/Library/Caches/pip/wheels/56/72/cc/86d8dbd1e3a8ef5470177cf6a4d25ec3cbebac55402e0ff4f0
# Successfully built wordcloud
